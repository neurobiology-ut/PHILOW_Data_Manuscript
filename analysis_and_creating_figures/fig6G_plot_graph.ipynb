# %%
library(googlesheets4)
library(ggplot2)
library(ggbeeswarm)
library(glue)
# Out:
# Warning message:
# "package 'ggbeeswarm' was built under R version 4.0.5"

# %%
ctrl_original_data <- read.csv("Z:/paper_data/2021_cristae/data_304_subvolume_analysis_of_tubular_lamellar//ctrl_raw.csv")
ctrl_original_data
# Out:
#       X   cluster_num mito tubular lamellar crop_no     tubular_ratio
# 1      1   1          5553 382      659     cropped_001 0.0687916442
# 2      2   2          4988 228      642     cropped_001 0.0457097033
# 3      3   3          5207   0     1654     cropped_001 0.0000000000
# 4      4   4          4614 328      411     cropped_001 0.0710879931
# 5      5   5          5867 358     1056     cropped_001 0.0610192603
# 6      6   6          5195   0     1715     cropped_001 0.0000000000
# 7      7   7          4798  33      447     cropped_001 0.0068778658
# 8      8   8          4928   0     1496     cropped_001 0.0000000000
# 9      9   9          4675   0      580     cropped_001 0.0000000000
# 10    10  10          5018 406        0     cropped_001 0.0809087286
# 11    11  11          5055 507        0     cropped_001 0.1002967359
# 12    12  12          5003 139      305     cropped_001 0.0277833300
# 13    13  13          4727 484      291     cropped_001 0.1023905225
# 14    14  14          4659  48        0     cropped_001 0.0103026401
# 15    15  15          4449 408       10     cropped_001 0.0917060013
# 16    16  16          4985   0     1915     cropped_001 0.0000000000
# 17    17  17          5543 770      685     cropped_001 0.1389139455
# 18    18  18          5015   0     1652     cropped_001 0.0000000000
# 19    19  19          5134 156        0     cropped_001 0.0303856642
# 20    20  20          5240 332      388     cropped_001 0.0633587786
# 21    21  21          5085  67        0     cropped_001 0.0131760079
# 22    22  22          4564 168       40     cropped_001 0.0368098160
# 23    23  23          5457 123        0     cropped_001 0.0225398571
# 24    24  24          5415 194     1100     cropped_001 0.0358264081
# 25    25  25          5207 732      121     cropped_001 0.1405799885
# 26    26  26          5043 315      791     cropped_001 0.0624628198
# 27    27  27          5236 632        0     cropped_001 0.1207028266
# 28    28  28          4801   1      807     cropped_001 0.0002082899
# 29    29  29          4888 451      360     cropped_001 0.0922667758
# 30    30  30          4997 286       27     cropped_001 0.0572343406
# ...   ... ...         ...  ...     ...      ...         ...
# 11660 103 103         4939   0     1683     cropped_005 0.0000000000
# 11661 104 104         5305   0     1528     cropped_005 0.0000000000
# 11662 105 105         4961   0     1215     cropped_005 0.0000000000
# 11663 106 106         5271 191        0     cropped_005 0.0362360083
# 11664 107 107         5149 526        0     cropped_005 0.1021557584
# 11665 108 108         5205 111     1567     cropped_005 0.0213256484
# 11666 109 109         4694   0        0     cropped_005 0.0000000000
# 11667 110 110         4858  44      321     cropped_005 0.0090572252
# 11668 111 111         4456   0     2178     cropped_005 0.0000000000
# 11669 112 112         4545  60      114     cropped_005 0.0132013201
# 11670 113 113         5136 505      122     cropped_005 0.0983255452
# 11671 114 114         4798   0     2439     cropped_005 0.0000000000
# 11672 115 115         5074   0      856     cropped_005 0.0000000000
# 11673 116 116         5048   0      784     cropped_005 0.0000000000
# 11674 117 117         5273 142        0     cropped_005 0.0269296416
# 11675 118 118         5363   0      870     cropped_005 0.0000000000
# 11676 119 119         4955   4     3211     cropped_005 0.0008072654
# 11677 120 120         4815  51     1921     cropped_005 0.0105919003
# 11678 121 121         5191  15      825     cropped_005 0.0028896166
# 11679 122 122         4885   0     2163     cropped_005 0.0000000000
# 11680 123 123         5186 716        0     cropped_005 0.1380640185
# 11681 124 124         5520   0     2822     cropped_005 0.0000000000
# 11682 125 125         5023   0     1274     cropped_005 0.0000000000
# 11683 126 126         4806   0     1059     cropped_005 0.0000000000
# 11684 127 127         4622   0     2042     cropped_005 0.0000000000
# 11685 128 128         5210   0      986     cropped_005 0.0000000000
# 11686 129 129         5322 556       62     cropped_005 0.1044720030
# 11687 130 130         5168 106     1180     cropped_005 0.0205108359
# 11688 131 131         5195   0      392     cropped_005 0.0000000000
# 11689 132 132         5293   0     2166     cropped_005 0.0000000000
#       lamellar_ratio
# 1     0.118674590
# 2     0.128708901
# 3     0.317649318
# 4     0.089076723
# 5     0.179989773
# 6     0.330125120
# 7     0.093163818
# 8     0.303571429
# 9     0.124064171
# 10    0.000000000
# 11    0.000000000
# 12    0.060963422
# 13    0.061561244
# 14    0.000000000
# 15    0.002247696
# 16    0.384152457
# 17    0.123579289
# 18    0.329411765
# 19    0.000000000
# 20    0.074045802
# 21    0.000000000
# 22    0.008764242
# 23    0.000000000
# 24    0.203139428
# 25    0.023237949
# 26    0.156851081
# 27    0.000000000
# 28    0.168089981
# 29    0.073649755
# 30    0.005403242
# ...   ...
# 11660 0.34075724
# 11661 0.28803016
# 11662 0.24491030
# 11663 0.00000000
# 11664 0.00000000
# 11665 0.30105668
# 11666 0.00000000
# 11667 0.06607657
# 11668 0.48877917
# 11669 0.02508251
# 11670 0.02375389
# 11671 0.50833681
# 11672 0.16870319
# 11673 0.15530903
# 11674 0.00000000
# 11675 0.16222264
# 11676 0.64803229
# 11677 0.39896158
# 11678 0.15892892
# 11679 0.44278403
# 11680 0.00000000
# 11681 0.51123188
# 11682 0.25363329
# 11683 0.22034956
# 11684 0.44180009
# 11685 0.18925144
# 11686 0.01164976
# 11687 0.22832817
# 11688 0.07545717
# 11689 0.40921972

# %%
options(repr.plot.width=10, repr.plot.height=10)

graph <- ggplot(NULL)

graph <- graph + labs(
    x = "Tubular/Mitochondria",
    y = "Lamellar/Mitochondria"
) + theme(
    axis.line = element_line(size = 2, colour="black"),
    axis.title.x = element_text(size = 30, face = "bold", family = "Helvetica", colour="black"),
    axis.title.y = element_text(size = 30, face = "bold", family = "Helvetica", colour="black"),
    axis.text.x = element_text(size = 20, face = "bold", family = "Helvetica", colour="black"),
    axis.text.y = element_text(size = 20, face = "bold", family = "Helvetica", colour="black"),
    panel.background = element_blank(), 
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank(),
) + scale_x_continuous (
    expand=c(0,0),
    limits=c(0, 1),
)+ scale_y_continuous (
    expand=c(0,0),
    limits=c(0, 1),
)


graph <- graph + geom_point(
    ctrl_original_data,
    mapping=aes(tubular_ratio, lamellar_ratio),
    size=3,
    alpha=0.3,
    beta=0.3
) 

graph
# Out:
# Warning message:
# "Ignoring unknown parameters: beta"
# Warning message in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)):
# " Windows のフォントデータベースにフォントファミリが見付かりません "
# Warning message in grid.Call(C_stringMetric, as.graphicsAnnot(x$label)):
# " Windows のフォントデータベースにフォントファミリが見付かりません "
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# " Windows のフォントデータベースにフォントファミリが見付かりません "
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# " Windows のフォントデータベースにフォントファミリが見付かりません "
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# " Windows のフォントデータベースにフォントファミリが見付かりません "
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# " Windows のフォントデータベースにフォントファミリが見付かりません "
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# " Windows のフォントデータベースにフォントファミリが見付かりません "
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# " Windows のフォントデータベースにフォントファミリが見付かりません "
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# " Windows のフォントデータベースにフォントファミリが見付かりません "
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# " Windows のフォントデータベースにフォントファミリが見付かりません "
# plot without title

# %%
dir.create("Z:/paper_data/2021_cristae/for_revision_#2/fig6G")
ggsave(file = "Z:/paper_data/2021_cristae/for_revision_#2/fig6G/ctrl_graph_001.svg", plot = graph, dpi = 100, width = 10, height = 10)
# Out:
# Warning message in dir.create("Z:/paper_data/2021_cristae/for_revision_#2/fig6G"):
# " 'Z:\paper_data\2021_cristae\for_revision_#2\fig6G' はすでに存在します "

# %%
kd_original_data <- read.csv("Z:/paper_data/2021_cristae/data_304_subvolume_analysis_of_tubular_lamellar//kd_raw.csv")

# %%
options(repr.plot.width=10, repr.plot.height=10)

graph <- ggplot(NULL)

graph <- graph + labs(
    x = "Tubular/Mitochondria",
    y = "Lamellar/Mitochondria"
) + theme(
    axis.line = element_line(size = 2, colour="black"),
    axis.title.x = element_text(size = 30, face = "bold", family = "Helvetica", colour="black"),
    axis.title.y = element_text(size = 30, face = "bold", family = "Helvetica", colour="black"),
    axis.text.x = element_text(size = 20, face = "bold", family = "Helvetica", colour="black"),
    axis.text.y = element_text(size = 20, face = "bold", family = "Helvetica", colour="black"),
    panel.background = element_blank(), 
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank(),
) + scale_x_continuous (
    expand=c(0,0),
    limits=c(0, 1),
)+ scale_y_continuous (
    expand=c(0,0),
    limits=c(0, 1),
)


graph <- graph + geom_point(
    kd_original_data,
    mapping=aes(tubular_ratio, lamellar_ratio),
    size=3,
    alpha=0.3,
    beta=0.3
) 

graph
# Out:
# Warning message:
# "Ignoring unknown parameters: beta"
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# " Windows のフォントデータベースにフォントファミリが見付かりません "
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# " Windows のフォントデータベースにフォントファミリが見付かりません "
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# " Windows のフォントデータベースにフォントファミリが見付かりません "
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# " Windows のフォントデータベースにフォントファミリが見付かりません "
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# " Windows のフォントデータベースにフォントファミリが見付かりません "
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# " Windows のフォントデータベースにフォントファミリが見付かりません "
# Warning message in grid.Call(C_textBounds, as.graphicsAnnot(x$label), x$x, x$y, :
# " Windows のフォントデータベースにフォントファミリが見付かりません "
# Warning message in grid.Call.graphics(C_text, as.graphicsAnnot(x$label), x$x, x$y, :
# " Windows のフォントデータベースにフォントファミリが見付かりません "
# plot without title

# %%
ggsave(file = "Z:/paper_data/2021_cristae/for_revision_#2/fig6G/kd_graph_001.svg", plot = graph, dpi = 100, width = 10, height = 10)
